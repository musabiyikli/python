# %%
a=0
ort = []
for q in range(5):
    print("-"*20)
    ogr = input("Öğrenci ismi: ")
    ogrvize = int(input("{} vize notu: " .format(ogr)))
    ogrproje = int(input("{} proje notu: " .format(ogr)))
    ogrfinal = int(input("{} final notu: " .format(ogr)))
    if q==0:
        logr1 = {"ogr": ogr, "ilk": ogrvize, "orta": ogrproje, "son" : ogrfinal}
        print("-"*20)
        print("İlk öğrenci kaydı gerçekleşti.")
        gecmenotu1=ogrvize*(0.3)+ogrproje*(0.3)+ogrfinal*(0.4)
        gecmenotu1=int(gecmenotu1)
        ort.append(gecmenotu1)
        logr1["ortalama"]=gecmenotu1
    elif q==1:
        logr2 = {"ogr": ogr, "ilk": ogrvize, "orta": ogrproje, "son" : ogrfinal}
        print("-"*20)
        print("İkinci öğrenci kaydı gerçekleşti.")
        gecmenotu2=ogrvize*(0.3)+ogrproje*(0.3)+ogrfinal*(0.4)
        gecmenotu2=int(gecmenotu2)
        ort.append(gecmenotu2)
        logr2["ortalama"]=gecmenotu2
    elif q==2:
        logr3 = {"ogr": ogr, "ilk": ogrvize, "orta": ogrproje, "son" : ogrfinal}
        print("-"*20)
        print("Üçüncü öğrenci kaydı gerçekleşti.")
        gecmenotu3=ogrvize*(0.3)+ogrproje*(0.3)+ogrfinal*(0.4)
        gecmenotu3=int(gecmenotu3)
        ort.append(gecmenotu3)
        logr3["ortalama"]=gecmenotu3
    elif q==3:
        logr4 = {"ogr": ogr, "ilk": ogrvize, "orta": ogrproje, "son" : ogrfinal}
        print("-"*20)
        print("Dördüncü öğrenci kaydı gerçekleşti.")
        gecmenotu4=ogrvize*(0.3)+ogrproje*(0.3)+ogrfinal*(0.4)
        gecmenotu4=int(gecmenotu4)
        ort.append(gecmenotu4)
        logr4["ortalama"]=gecmenotu4
    elif q==4:
        logr5 = {"ogr": ogr, "ilk": ogrvize, "orta": ogrproje, "son" : ogrfinal}
        print("-"*20)
        print("Beşinci öğrenci kaydı gerçekleşti.")
        gecmenotu5=ogrvize*(0.3)+ogrproje*(0.3)+ogrfinal*(0.4)
        gecmenotu5=int(gecmenotu5)
        ort.append(gecmenotu5)
        logr5["ortalama"]=gecmenotu5
print("-"*20)
print("Öğrenci kayıt işlemi tamamlandı. Öğrenci Mevcudu: 5")

ort.sort(reverse=True)

while a<5:
    for a in range(1):
        if len(ort)==0:
            print("-"*20)
            print("Not hesaplama işlemi tamamlandı.")
            print("-"*20)
            a+=5
            break
        elif max(ort)==logr1["ortalama"]:
            print("-"*20)
            print("Öğrenci Adı:", logr1["ogr"])
            print("Öğrenci Vize Notu:", logr1["ilk"])
            print("Öğrenci Proje Notu:", logr1["orta"])
            print("Öğrenci Final Notu", logr1["son"])
            print("Öğrenci Ortalaması:", gecmenotu1)
            ort.pop(0)
            a+=1
        elif max(ort)==logr2["ortalama"]:
            print("-"*20)
            print("Öğrenci Adı:", logr2["ogr"])
            print("Öğrenci Vize Notu:", logr2["ilk"])
            print("Öğrenci Proje Notu:", logr2["orta"])
            print("Öğrenci Final Notu", logr2["son"])
            print("Öğrenci Ortalaması:", gecmenotu2)
            ort.pop(0)
            a+=1
        elif max(ort)==logr3["ortalama"]:
            print("-"*20)
            print("Öğrenci Adı:", logr3["ogr"])
            print("Öğrenci Vize Notu:", logr3["ilk"])
            print("Öğrenci Proje Notu:", logr3["orta"])
            print("Öğrenci Final Notu", logr3["son"])
            print("Öğrenci Ortalaması:", gecmenotu3)
            ort.pop(0)
            a+=1
        elif max(ort)==logr4["ortalama"]:
            print("-"*20)
            print("Öğrenci Adı:", logr4["ogr"])
            print("Öğrenci Vize Notu:", logr4["ilk"])
            print("Öğrenci Proje Notu:", logr4["orta"])
            print("Öğrenci Final Notu", logr4["son"])
            print("Öğrenci Ortalaması:", gecmenotu4)
            ort.pop(0)
            a+=1
        elif max(ort)==logr5["ortalama"]:
            print("-"*20)
            print("Öğrenci Adı:", logr5["ogr"])
            print("Öğrenci Vize Notu:", logr5["ilk"])
            print("Öğrenci Proje Notu:", logr5["orta"])
            print("Öğrenci Final Notu", logr5["son"])
            print("Öğrenci Ortalaması:", gecmenotu5)
            ort.pop(0)
            a+=1
            
#Musa Bıyıklı musabiyikli@hotmail.com.tr
# Out:
# --------------------
# Öğrenci ismi: Furkan Akkulak
# Furkan Akkulak vize notu: 93
# Furkan Akkulak proje notu: 50
# Furkan Akkulak final notu: 35
# --------------------
# İlk öğrenci kaydı gerçekleşti.
# --------------------
# Öğrenci ismi: Onur Sever
# Onur Sever vize notu: 90
# Onur Sever proje notu: 40
# Onur Sever final notu: 60
# --------------------
# İkinci öğrenci kaydı gerçekleşti.
# --------------------
# Öğrenci ismi: Murat Türker
# Murat Türker vize notu: 75
# Murat Türker proje notu: 65
# Murat Türker final notu: 84
# --------------------
# Üçüncü öğrenci kaydı gerçekleşti.
# --------------------
# Öğrenci ismi: Ahmet Furkan Orhan
# Ahmet Furkan Orhan vize notu: 36
# Ahmet Furkan Orhan proje notu: 85
# Ahmet Furkan Orhan final notu: 45
# --------------------
# Dördüncü öğrenci kaydı gerçekleşti.
# --------------------
# Öğrenci ismi: Musa Bıyıklı
# Musa Bıyıklı vize notu: 90
# Musa Bıyıklı proje notu: 68
# Musa Bıyıklı final notu: 87
# --------------------
# ...
