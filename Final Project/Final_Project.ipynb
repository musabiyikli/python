# %%
soru = ["Üçgenin iç açılarının toplamı kaçtır? ",
        "Prizlerde kullandığımız standart elektrik voltajı kaç volttur? ",
        "NBA kurallarına göre standart bir basketbol potasının yerden yüksekliği nedir? (feet cinsinden) ",
        "İstanbul kaç yılında fethedilmiştir? ",
        "Mustafa Kemal Atatürk kaç yılında doğmuştur? ",
        "Türkiye Cumhuriyeti hangi yılda kurulmuştur? ",
        "Türkiye Cumhuriyeti'nde ilk banka hangi yılda kurulmuştur? ",
        "Arabalarıyla piyasada yeni bir dönem başlatan, ismini ünlü bir mucitten alan şirketin adı nedir? ",
        "İlk Türk realist romanın yazarı kimdir? (Yazar ismini sadece ilk harfleri büyük şekilde yazınız.) ",
        "1984 adlı kitabın yazarı kimdir? (Yazar ismini sadece ilk harfleri büyük şekilde yazınız.) "]
cevap = [180,220,10,1453,1881,1923,1924,"Tesla","Recaizade Mahmut Ekrem","George Orwell"]
dogru=0
yanlıs=0
print("***                           Yarışmama                               ***\n**                           Hoşgeldiniz!                              **")
print("-"*74)
print("Hazırlayan: Musa Bıyıklı   iletişim: musabiyikli@hotmail.com.tr")
print("-"*74)
print("YARIŞMA KURALLARI\nSizden istenen cevaplar eğer sayı talep ediliyorsa sayı şeklinde yazınız. Mesela cevap yıl olması gerekliyse 2011 gibi bir cevap vermelisiniz. Mesela bir isim isteniyorsa mutlaka her kelimenin baş harfi büyük olmalıdır. Aksi taktirde sorunuz yanlış kabul edilir ve o soru yanlış sayılır. Toplamda 10 soru bulunmaktadır. Bu soruların %50'den fazlasını yaparsınız başarılı olursunuz.\nİyi şanslar!")
print("-"*74)
basla=input("Hazır olduğunuz zaman 'Hazırım' yazınız: ")
if basla=="Hazırım":
    for i in range(11):
        if i == 0:
            print("-"*74)
            birincisoru=input(soru[0])
            try:
                a=int(birincisoru)
            except ValueError:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[0]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
                continue
            if birincisoru=="180":
                print("-"*74)
                print("Doğru cevap. Diğer soruya geçiliyor.")
                dogru+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
            else:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[0]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
        elif i==1:
            print("-"*74)
            ikincisoru=input(soru[1])
            try:
                b=int(ikincisoru)
            except ValueError:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[1]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
                continue
            if ikincisoru=="220":
                print("-"*74)
                print("Doğru cevap. Diğer soruya geçiliyor.")
                dogru+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
            else:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[1]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
        elif i==2:
            print("-"*74)
            ucuncusoru=input(soru[2])
            try:
                c=int(ucuncusoru)
            except ValueError:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[2]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
                continue
            if ucuncusoru=="10":
                print("-"*74)
                print("Doğru cevap. Diğer soruya geçiliyor.")
                dogru+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
            else:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[2]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
        elif i==3:
            print("-"*74)
            dorduncusoru=input(soru[3])
            try:
                d=int(dorduncusoru)
            except ValueError:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[3]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
                continue
            if dorduncusoru=="1453":
                print("-"*74)
                print("Doğru cevap. Diğer soruya geçiliyor.")
                dogru+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
            else:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[3]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
        elif i==4:
            print("-"*74)
            besincisoru=input(soru[4])
            try:
                e=int(besincisoru)
            except ValueError:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[4]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
                continue
            if besincisoru=="1881":
                print("-"*74)
                print("Doğru cevap. Diğer soruya geçiliyor.")
                dogru+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
            else:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[4]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
        elif i==5:
            print("-"*74)
            altıncısoru=input(soru[5])
            try:
                f=int(altıncısoru)
            except ValueError:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[5]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
                continue
            if altıncısoru=="1923":
                print("-"*74)
                print("Doğru cevap. Diğer soruya geçiliyor.")
                dogru+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
            else:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[5]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
        elif i==6:
            print("-"*74)
            yedincisoru=input(soru[6])
            try:
                g=int(yedincisoru)
            except ValueError:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[6]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
                continue
            if yedincisoru=="1924":
                print("-"*74)
                print("Doğru cevap. Diğer soruya geçiliyor.")
                dogru+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
            else:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[6]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
        elif i==7:
            print("-"*74)
            sekizincisoru=input(soru[7])
            try:
                h=str(sekizincisoru)
            except ValueError:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[7]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
                continue
            if sekizincisoru=="Tesla":
                print("-"*74)
                print("Doğru cevap. Diğer soruya geçiliyor.")
                dogru+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
            else:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[7]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
        elif i==8:
            print("-"*74)
            dokuzuncusoru=input(soru[8])
            try:
                a=str(dokuzuncusoru)
            except ValueError:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[8]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
                continue
            if dokuzuncusoru=="Recaizade Mahmut Ekrem":
                print("-"*74)
                print("Doğru cevap. Diğer soruya geçiliyor.")
                dogru+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
            else:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[8]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
        elif i==9:
            print("-"*74)
            onuncusoru=input(soru[9])
            try:
                a=str(onuncusoru)
            except ValueError:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[9]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
                continue
            if onuncusoru=="George Orwell":
                print("-"*74)
                print("Doğru cevap. Diğer soruya geçiliyor.")
                dogru+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
            else:
                print("-"*74)
                print("Yanlış cevap. Diğer soruya geçiliyor.")
                print("Doğru cevap: {}".format(cevap[9]))
                yanlıs+=10
                print("-"*74)
                print("Puanınız: {}".format(dogru))
        else:
            print("-"*74)
            print("Yarışma tamamlandı...")
            print("Doğru Sayısı:{}".format(int(dogru/10)))
            print("Yanlış Sayısı:{}".format(int(yanlıs/10)))
            if dogru<yanlıs or dogru==yanlıs:
                print("-"*74)
                print("Maalesef yarışmayı kazanamadınız.")
            else:
                print("-"*74)
                print("Tebrikler yarışmayı kazandınız. Puanınız: {}/100".format(dogru))
else:
    print("-"*74)
    print("Hazır olduğun zaman tekrar başlayabiliriz.")
    print("Yarışma iptal edildi")
        
#Musa Bıyıklı  musabiyikli@hotmail.com.tr
